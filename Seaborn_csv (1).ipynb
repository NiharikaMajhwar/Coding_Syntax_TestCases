# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/admin/Downloads/auto_data (1).csv",encoding='ISO-8859-1')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation_matrix = df.corr()

# Visualize correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Between Variables")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8904\1220216481.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Bar plot of mean values
plt.figure(figsize=(10, 6))
df.mean().plot(kind="bar")
plt.title("Mean Value Representation")
plt.ylabel("Mean Value")
plt.xlabel("Variables")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8904\2758526948.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().plot(kind="bar")

# %%
# Line plot of mean values
plt.figure(figsize=(10, 6))
df.mean().plot(kind="line", marker="o")
plt.title("Mean Value Representation")
plt.ylabel("Mean Value")
plt.xlabel("Variables")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8904\3670261367.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().plot(kind="line", marker="o")

# %%
# Box plot of mean values
plt.figure(figsize=(10, 6))
sns.boxplot(df=df) 
plt.title("Box Plot of Mean Values")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.show()

# %%
# Convert 'horsepower' to numeric (if not already)
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# Filter the data based on the conditions
filtered_data = df[(df['acceleration'] > 15) & (df['horsepower'] < 170)]

# Extract the names of the vehicles
vehicle_names = filtered_data['name']

# Print the vehicle names
print("Vehicle names where acceleration > 15 and horsepower < 170:")
print(vehicle_names)
# Out:
# Vehicle names where acceleration > 15 and horsepower < 170:
# 15                  plymouth duster
# 16                       amc hornet
# 17                    ford maverick
# 19     volkswagen 1131 deluxe sedan
# 20                      peugeot 504
#                    ...
# 392                chevrolet camaro
# 393                 ford mustang gl
# 394                       vw pickup
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 211, dtype: object

# %%
# Grouping by 'cylinders' and counting unique values
cylinder_counts = df.groupby('cylinders')['cylinders'].count()

# Print the cylinder counts
print("Number of vehicles for each cylinder type:")
print(cylinder_counts)
# Out:
# Number of vehicles for each cylinder type:
# cylinders
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# Name: cylinders, dtype: int64

# %%
# Grouping by 'model_year' and counting unique values
vehicles_per_year = df.groupby('model_year')['model_year'].count()

# Print the count of vehicles per year
print("Number of vehicles for every model year:")
print(vehicles_per_year)
# Out:
# Number of vehicles for every model year:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: model_year, dtype: int64
